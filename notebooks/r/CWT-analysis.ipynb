# %%
source("C:/Users/Tom Work/PycharmProjects/twipsy-lite/ts.R")
# Out:
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: timeDate
# This is forecast 7.1

# %%
pair = preprocessing('E:/summary/sept_casual.csv', 'E:/summary/sept_total.csv')
sept_cas = ts(pair$series[25:696], frequency=24)
sept_tot = ts(pair$total[25:696], frequency=24)
# Out:
#  [1] 408 409 410 411 412 413 414 415 476 477 478 479 485 486 721 722 723 724 725

# %%
june_cas = ts(preprocessing('E:/summary/june_casual.csv', 'E:/summary/june_total.csv')$series[49:720], frequency=24)
june_tot = ts(preprocessing('E:/summary/june_casual.csv', 'E:/summary/june_total.csv')$total[49:720], frequency=24)
# Out:
#  [1]   2   3   4   5   6   7  26  27  28  29  30  31 721 722 723
#  [1]   2   3   4   5   6   7  26  27  28  29  30  31 721 722 723

# %%
sept_perc = sept_cas/sept_tot

# %%
june_perc = june_cas/june_tot

# %%
sept_cwt = wavCWT(sept_perc, wavelet='gaussian2', n.scale = 800, scale.range =c(0.05, 7))
cwt.s= as.matrix(sept_cwt)

# %%
june_cwt = wavCWT(june_perc, wavelet='gaussian2', n.scale = 800, scale.range =c(0.05, 7))
cwt.j= as.matrix(june_cwt)

# %%
june_cwt
# Out:
# Continuous Wavelet Transform of june_perc
# -----------------------------------------
# Wavelet           : Mexican Hat (Gaussian, second derivative)
# Wavelet variance  : 1
# Length of series  : 672
# Sampling interval : 0.04166667
# Number of scales  : 168
# Range of scales   : 0.0416666666666667 to 7

# %%
plot(sept_perc)
# Out:
# plot without title

# %%
plot(cwt.s[,k] -cwt.j[,k], type='l')
# Out:
# plot without title

# %%
k = 7
plot.ts(cbind(cwt.s[,k], cwt.j[,k]), type='l', main='Comparing CWT between Sept June')
# Out:
# plot without title

# %%
acf(cwt.s[,k])
# Out:
# Plot with title "Series  cwt.s[, k]"

# %%
ccf(cwt.s[,k], cwt.j[,k])
# Out:
# Plot with title "cwt.s[, k] & cwt.j[, k]"

# %%
plot(cwt.j[,6], type='l')
# Out:
# plot without title

# %%
j = 35
plot.ts(cbind(cwt.s[,j], cwt.j[,j]), type='l', main='Comparing CWT between Sept June')
# Out:
# plot without title
